# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture

def plot_clusters(X, labels, centers, title):
    plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', s=50)
    plt.scatter(centers[:, 0], centers[:, 1], marker='*', color='black', s=100, alpha=0.7)
    plt.title(title)
    plt.xlabel('V1')
    plt.ylabel('V2')
    plt.show()

data = pd.read_csv("Kmeans.csv")
X = data[['V1', 'V2']].values
plt.scatter(f1, f2, c='black', s=7)
plt.title('Dataset')
plt.show()
for n_clusters in [3, 4]:
    kmeans = KMeans(n_clusters=n_clusters)
    kmeans.fit(X)
    kmeans_labels = kmeans.predict(X)
    kmeans_centers = kmeans.cluster_centers_

    plot_clusters(X, kmeans_labels, kmeans_centers, f'KMeans with {n_clusters} Clusters')

    print(f"Centroids for k={n_clusters}:")
    print(kmeans_centers)

    gmm = GaussianMixture(n_components=n_clusters)
    gmm.fit(X)
    gmm_labels = gmm.predict(X)

    plot_clusters(X, gmm_labels, gmm.means_, f'GMM with {n_clusters} Components')

    print(f"EM predictions for {n_clusters} components:")
    print(gmm.predict_proba(X))
    print(f"Means for {n_clusters} components:")
    print(gmm.means_)
    print(f"Covariances for {n_clusters} components:")
    print(gmm.covariances_)
# Out:
# /home/himanshu/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Centroids for k=3:
# [[ 40.68362784  59.71589274]
#  [ 69.92418447 -10.11964119]
#  [  9.4780459   10.686052  ]]
# EM predictions for 3 components:
# [[2.47857809e-09 1.51560970e-12 9.99999998e-01]
#  [3.50898583e-07 4.99388810e-06 9.99994655e-01]
#  [1.79826264e-10 3.06364433e-10 1.00000000e+00]
#  ...
#  [9.99999967e-01 5.88532728e-13 3.31608645e-08]
#  [1.00000000e+00 1.18181069e-16 3.40814080e-15]
#  [9.99999999e-01 1.17363874e-17 7.83207859e-10]]
# Means for 3 components:
# [[ 69.89436808 -10.11243325]
#  [ 40.68585643  59.70939105]
#  [  9.46516999  10.71326558]]
# Covariances for 3 components:
# [[[110.42521599  -0.60038245]
#   [ -0.60038245 106.47434137]]
#
#  [[103.11540751  -1.82258688]
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture

def plot_clusters(X, labels, centers, title):
    plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', s=50)
    plt.scatter(centers[:, 0], centers[:, 1], marker='*', color='black', s=100, alpha=0.7)
    plt.title(title)
    plt.xlabel('V1')
    plt.ylabel('V2')
    plt.show()

data = pd.read_csv("Kmeans.csv")
X = data[['V1', 'V2']].values

plt.scatter(X[:, 0], X[:, 1], c='black', s=7)
plt.title('Dataset')
plt.show()

for n_clusters in [3, 4]:
    kmeans = KMeans(n_clusters=n_clusters).fit(X)
    plot_clusters(X, kmeans.labels_, kmeans.cluster_centers_, f'KMeans with {n_clusters} Clusters')
    print(f"Centroids for k={n_clusters}:", kmeans.cluster_centers_)
    print(f"EM predictions for {n_clusters} components:")
    print(gmm.predict_proba(X))
    print(f"Means for {n_clusters} components:", gmm.means_)
    print(f"Covariances for {n_clusters} components:")
    print(gmm.covariances_)
    gmm = GaussianMixture(n_components=n_clusters).fit(X)
    plot_clusters(X, gmm.predict(X), gmm.means_, f'GMM with {n_clusters} Components')
# Out:
# /home/himanshu/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Centroids for k=3: [[ 69.92418447 -10.11964119]
#  [ 40.68362784  59.71589274]
#  [  9.4780459   10.686052  ]]
# EM predictions for 3 components:
# [[9.99999999e-01 3.16415329e-13 1.50993281e-12 1.30662836e-09]
#  [9.99994720e-01 5.00029589e-08 4.98674635e-06 2.43030748e-07]
#  [1.00000000e+00 3.97671164e-13 3.05595570e-10 1.41090522e-10]
#  ...
#  [3.65627025e-08 3.17675443e-01 6.41287235e-13 6.82324520e-01]
#  [3.11366296e-15 8.82692295e-01 1.06014082e-16 1.17307705e-01]
#  [7.19505154e-10 3.15828427e-02 1.05822828e-17 9.68417157e-01]]
# Means for 3 components: [[  9.46679266  10.71168998]
#  [ 73.82015134  -4.69648781]
#  [ 40.6863007   59.70950906]
#  [ 66.03831913 -15.43706473]]
# ...
